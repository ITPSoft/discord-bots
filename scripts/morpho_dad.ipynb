# %%
str1 = "jsem expert na prsteny a trouba"
str2 = "doběhl jsem maraton"
str3 = "To jsou věci, co jsem prostě líný googlit, takže třeba když hledám inflaci rumunska, použiju AI."
keyword = ["jsem"]

# %%
from ufal.morphodita import Tagger, Forms, TaggedLemmas, TokenRanges, Morpho, TaggedLemmasForms
from šimek.utils import parse_sentence_with_keyword
# Out:
# Loading tagger:
# Tagger loaded.

# %%
toks1, word_count1, keyword_idx1, _ = parse_sentence_with_keyword(str1, keyword, False)
toks2, word_count2, keyword_idx2, _ = parse_sentence_with_keyword(str2, keyword, False)
toks3, word_count3, keyword_idx3, _ = parse_sentence_with_keyword(str3, keyword, False)
